# %% [markdown]
# ### maplotlib画图
#
# 更详细的教程  https://www.runoob.com/numpy/numpy-matplotlib.html
#
# 安装

# %%
# !pip3 install matplotlib

# %%
import numpy as np 
from matplotlib import pyplot as plt 
# %matplotlib inline

x = np.arange(1,11) 
y =  2  * x +  5 

plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 

plt.plot(x,y) 

#plt.savefig("output/matplotlib_demo.png")
plt
#plt.show()  在py文件中使用
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
plt.savefig("output/matplotlib_demo.png")

# %%
import numpy as np 
from matplotlib import pyplot as plt 
# %matplotlib inline

x = np.arange(1,11) 
y =  2  * x +  5 
plt.title("Matplotlib示例") 
plt.xlabel("x轴") 
plt.ylabel("y轴") 
plt.plot(x,y) 
#plt.savefig("output/matplotlib_demo.png")
plt
#plt.show()  在py文件中使用
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# 在mac电脑中上面的代码声明是无效的，而且最关键的是代码不好记住。
#
#
# 在使用基于matplotlib的库画图时，结合Pyplotz，无需繁琐的配置环境就可以显示中文
#
# ### 安装pyplotz

# %%
# !pip3 install pyplotz
# Out:
# ...
#   Running setup.py install for pyplotz ... done
# ...

# %%
下面我们重新绘图，大家如果熟悉matplotlib就会很容易的看懂

# %%
from pyplotz.pyplotz import PyplotZ
from pyplotz.pyplotz import plt
import numpy as np
# %matplotlib inline


pltz = PyplotZ()
pltz.enable_chinese() #支持中文

x = np.arange(1,11) 
y =  2  * x +  5 

pltz.set_figure_size(10, 5) #设置画布尺寸
#x，y, 线条颜色, label图例名字, alpha透明度（范围从0到1）
pltz.plot(x, y)#, 'y', label='y2分布', alpha=0.7)

#坐标的名字
pltz.xlabel('x')
pltz.ylabel('y')

#显示图例，loc设置图例的位置为右上角
pltz.legend(loc='upper right') 
#自动设置字体大小
pltz.automate_font_size()
# Out:
# try downloading
# start downloading default chinese font(only for first time)
